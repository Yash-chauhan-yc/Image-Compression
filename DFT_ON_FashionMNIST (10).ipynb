# %% [markdown]
# #DISCRETE FOURIER TRANSFORM(DFT)

# %% [markdown]
# ##Importing Essential libraries

# %%
from PIL import Image
import cmath
from skimage import io, transform
import sys
import numpy as np
import cv2
from matplotlib import pyplot as plt

# %%
pi2 = cmath.pi * 2.0

# %% [markdown]
# ###Reading 10 images of fashion_mnist dataset

# %%
img0 = cv2.imread('/content/00000.jpg',0)
img2 = cv2.imread('/content/00003.jpg',0)
img1 = cv2.imread('/content/00005.jpg',0)
img3 = cv2.imread('/content/00001.jpg',0)
img4 = cv2.imread('/content/00002.jpg',0)
img5 = cv2.imread('/content/00004.jpg',0)
img6 = cv2.imread('/content/00006.jpg',0)
img7 = cv2.imread('/content/00007.jpg',0)
img8 = cv2.imread('/content/00008.jpg',0)
img9 = cv2.imread('/content/00009.jpg',0)

# %% [markdown]
# ###Displaying images

# %%
# create figure
fig = plt.figure(figsize=(15, 12))
  
# setting values to rows and column variables
rows = 4
columns = 3
    
# Adds a subplot at the 1st position
fig.add_subplot(rows, columns, 1)
  
# showing image
plt.imshow(img0, cmap='gray')
plt.axis('off')
plt.title("First")
  
# Adds a subplot at the 2nd position
fig.add_subplot(rows, columns, 2)
  
# showing image
plt.imshow(img1, cmap='gray')
plt.axis('off')
plt.title("Second")
  
# Adds a subplot at the 3rd position
fig.add_subplot(rows, columns, 3)
  
# showing image
plt.imshow(img2, cmap='gray')
plt.axis('off')
plt.title("Third")
  
# Adds a subplot at the 4th position
fig.add_subplot(rows, columns, 4)
  
# showing image
plt.imshow(img3, cmap='gray')
plt.axis('off')
plt.title("Fourth")

# Adds a subplot at the 4th position
fig.add_subplot(rows, columns, 5)
  
# showing image
plt.imshow(img4, cmap='gray')
plt.axis('off')
plt.title("Fifth")

# Adds a subplot at the 4th position
fig.add_subplot(rows, columns, 6)
  
# showing image
plt.imshow(img5, cmap='gray')
plt.axis('off')
plt.title("Sixth")

# Adds a subplot at the 4th position
fig.add_subplot(rows, columns, 7)
  
# showing image
plt.imshow(img6, cmap='gray')
plt.axis('off')
plt.title("Seventh")

# Adds a subplot at the 4th position
fig.add_subplot(rows, columns, 8)
  
# showing image
plt.imshow(img7, cmap='gray')
plt.axis('off')
plt.title("Eight")

# Adds a subplot at the 4th position
fig.add_subplot(rows, columns, 9)
  
# showing image
plt.imshow(img8, cmap='gray')
plt.axis('off')
plt.title("Ninth")

# Adds a subplot at the 4th position
fig.add_subplot(rows, columns, 10)
  
# showing image
plt.imshow(img9, cmap='gray')
plt.axis('off')
plt.title("Tenth")
# Out:
# Text(0.5, 1.0, 'Tenth')

# %% [markdown]
# ##Defining function for Discrete Fourier Transform(DFT)

# %%
def Discrete_FouriorT_2D(image):
    global M, N
    (M, N) = image.size
    # Creating a 2D matrix of M x N Containing zeroes
    channel_gray = np.zeros([M, N], dtype=complex)
    # load() Allocates storage for the image and loads the pixel data
    pixels = image.load()
    for k in range(M):
        print("DFT - ", k)
        for l in range(N):
            sum_gray = 0.0

            for m in range(M):
                for n in range(N):
                    gray = pixels[m, n]
                    e = cmath.exp(- 1j * pi2 * (float(k * m) / M + float(l * n) / N))
                    sum_gray += gray * e
                    channel_gray[l][k] = sum_gray / M / N
    return (channel_gray)

# %% [markdown]
# ###Resizing images

# %%
# Resizing Image so that prccess can be carried out fastly
resized_img0 = transform.resize(img0, (64, 64))
resized_img1 = transform.resize(img1, (64, 64))
resized_img2 = transform.resize(img2, (64, 64))
resized_img3 = transform.resize(img3, (64, 64))
resized_img4 = transform.resize(img4, (64, 64))
resized_img5 = transform.resize(img5, (64, 64))
resized_img6 = transform.resize(img6, (64, 64))
resized_img7 = transform.resize(img7, (64, 64))
resized_img8 = transform.resize(img8, (64, 64))
resized_img9 = transform.resize(img9, (64, 64))

# %%
# Saving Resized Image
io.imsave("resized-0.jpg", resized_img0)
io.imsave("resized-1.jpg", resized_img1)
io.imsave("resized-2.jpg", resized_img2)
io.imsave("resized-3.jpg", resized_img3)
io.imsave("resized-4.jpg", resized_img4)
io.imsave("resized-5.jpg", resized_img5)
io.imsave("resized-6.jpg", resized_img6)
io.imsave("resized-7.jpg", resized_img7)
io.imsave("resized-8.jpg", resized_img8)
io.imsave("resized-9.jpg", resized_img9)

# %%
# Opening Resized Image
image0 = Image.open("resized-0.jpg")
image1 = Image.open("resized-1.jpg")
image2 = Image.open("resized-2.jpg")
image3 = Image.open("resized-3.jpg")
image4 = Image.open("resized-4.jpg")
image5 = Image.open("resized-5.jpg")
image6 = Image.open("resized-6.jpg")
image7 = Image.open("resized-7.jpg")
image8 = Image.open("resized-8.jpg")
image9 = Image.open("resized-9.jpg")

# %% [markdown]
# ##Applying DFT on images

# %%
# Applying DFT
DFT0 = Discrete_FouriorT_2D(image0)
DFT1 = Discrete_FouriorT_2D(image1)
DFT2 = Discrete_FouriorT_2D(image2)
DFT3 = Discrete_FouriorT_2D(image3)
DFT4 = Discrete_FouriorT_2D(image4)
DFT5 = Discrete_FouriorT_2D(image5)
DFT6 = Discrete_FouriorT_2D(image6)
DFT7 = Discrete_FouriorT_2D(image7)
DFT8 = Discrete_FouriorT_2D(image8)
DFT9 = Discrete_FouriorT_2D(image9)

# %%
# The output of DFT consists of complex values, in order to display it we need perform following calculation
DFT_Display0 = 20*np.log10(np.abs(DFT0))
DFT_Display1 = 20*np.log10(np.abs(DFT1))
DFT_Display2 = 20*np.log10(np.abs(DFT2))
DFT_Display3 = 20*np.log10(np.abs(DFT3))
DFT_Display4 = 20*np.log10(np.abs(DFT4))
DFT_Display5 = 20*np.log10(np.abs(DFT5))
DFT_Display6 = 20*np.log10(np.abs(DFT6))
DFT_Display7 = 20*np.log10(np.abs(DFT7))
DFT_Display8 = 20*np.log10(np.abs(DFT8))
DFT_Display9 = 20*np.log10(np.abs(DFT9))

# %% [markdown]
# ###Displaying images on which DFT is applied

# %%
# create figure
fig = plt.figure(figsize=(15, 12))
  
# setting values to rows and column variables
rows = 4
columns = 3
    
# Adds a subplot at the 1st position
fig.add_subplot(rows, columns, 1)
  
# showing image
plt.imshow(DFT_Display0, cmap='gray')
plt.axis('off')
plt.title("First")
  
# Adds a subplot at the 2nd position
fig.add_subplot(rows, columns, 2)
  
# showing image
plt.imshow(DFT_Display1, cmap='gray')
plt.axis('off')
plt.title("Second")
  
# Adds a subplot at the 3rd position
fig.add_subplot(rows, columns, 3)
  
# showing image
plt.imshow(DFT_Display2, cmap='gray')
plt.axis('off')
plt.title("Third")
  
# Adds a subplot at the 4th position
fig.add_subplot(rows, columns, 4)
  
# showing image
plt.imshow(DFT_Display3, cmap='gray')
plt.axis('off')
plt.title("Fourth")

# Adds a subplot at the 4th position
fig.add_subplot(rows, columns, 5)
  
# showing image
plt.imshow(DFT_Display4, cmap='gray')
plt.axis('off')
plt.title("Fifth")

# Adds a subplot at the 4th position
fig.add_subplot(rows, columns, 6)
  
# showing image
plt.imshow(DFT_Display5, cmap='gray')
plt.axis('off')
plt.title("Sixth")

# Adds a subplot at the 4th position
fig.add_subplot(rows, columns, 7)
  
# showing image
plt.imshow(DFT_Display6, cmap='gray')
plt.axis('off')
plt.title("Seventh")

# Adds a subplot at the 4th position
fig.add_subplot(rows, columns, 8)
  
# showing image
plt.imshow(DFT_Display7, cmap='gray')
plt.axis('off')
plt.title("Eight")

# Adds a subplot at the 4th position
fig.add_subplot(rows, columns, 9)
  
# showing image
plt.imshow(DFT_Display8, cmap='gray')
plt.axis('off')
plt.title("Ninth")

# Adds a subplot at the 4th position
fig.add_subplot(rows, columns, 10)
  
# showing image
plt.imshow(DFT_Display9, cmap='gray')
plt.axis('off')
plt.title("Tenth")
# Out:
# Text(0.5, 1.0, 'Tenth')

# %% [markdown]
# ###Saving DFT images

# %%
# Saving output of DFT
plt.imsave('DFT0.png', DFT_Display0, cmap='gray')
plt.imsave('DFT1.png', DFT_Display1, cmap='gray')
plt.imsave('DFT2.png', DFT_Display2, cmap='gray')
plt.imsave('DFT3.png', DFT_Display3, cmap='gray')
plt.imsave('DFT4.png', DFT_Display4, cmap='gray')
plt.imsave('DFT5.png', DFT_Display5, cmap='gray')
plt.imsave('DFT6.png', DFT_Display6, cmap='gray')
plt.imsave('DFT7.png', DFT_Display7, cmap='gray')
plt.imsave('DFT8.png', DFT_Display8, cmap='gray')
plt.imsave('DFT9.png', DFT_Display9, cmap='gray')

# %% [markdown]
# ##Defining function for Inverse Discrete Fourier Transform(IDFT)

# %%
def Inverse_Discrete_FouriorT_2D(dft2d):
    dft2d_gray = dft2d
    global M, N
    # Creates a new image with the given mode and size. L is a flag used for GrayScale images
    image = Image.new("L", (M, N))
    # load() Allocates storage for the image and loads the pixel data
    pixels = image.load()
    for m in range(M):
        print("IDFT - ", m)
        for n in range(N):
            sum_gray = 0.0
            for k in range(M):
                for l in range(N):
                    e = cmath.exp(1j * pi2 * (float(k * m) / M + float(l * n) / N))
                    sum_gray += dft2d_gray[l][k] * e
            gray = int(sum_gray.real + 0.5)
            pixels[m, n] = (gray)
    return image

# %% [markdown]
# ###Applying IDFT on images

# %%
Output0 = Inverse_Discrete_FouriorT_2D(DFT0)

# %% [markdown]
# ###Displaying IDFT images

# %%
plt.subplot(133),plt.imshow(Output0,cmap='gray')
# Out:
# (<matplotlib.axes._subplots.AxesSubplot at 0x7fbe7de92810>,
#  <matplotlib.image.AxesImage at 0x7fbe7c4dfdd0>)

# %% [markdown]
# ###Saving IDFT images

# %%
# Saving output of IDFT
plt.imsave("IDFT.png", Output0, cmap='gray')
